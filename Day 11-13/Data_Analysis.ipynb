# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1705e31f-42a8-4714-882b-6bf5cc24cd61" name="files[]" multiple disabled />
#      <output id="result-1705e31f-42a8-4714-882b-6bf5cc24cd61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving People disappeared during Maoist war.csv to People disappeared during Maoist war.csv
# {'People disappeared during Maoist war.csv': b"Missing/Dead,District,Zone,Geographical Region,Development Region,Full Name,Gender,Date of Birth,Year of birth,Place Of Birth,Father'S Name,Date of disapperance,Year of disaaperance,Place of disapperance,District of disapperance\nDeath,Achham,Seti,Hill,Far-Western,Bhoj Bahadur Mijar,M,00/00/1972,1972,Achham,Bhaire Mijar,20/11/2002,2002,Dipayal,Doti\nDeath,Achham,Seti,Hill,Far-Western,Dabal Bahadur Saud,M,00/11/1959,1959,Achham,Dal Bahadur Saud,3/9/2004,2004,Ramarosan,Achham\nDeath,Achham,Seti,Hill,Far-Western,Padam Raj Neupane,M,00/00/1985,1985,Achham,Umakanta Neupane,5/3/2005,2005,Batulasen,Achham\nDeath,Arghakhanchi,Lumbini,Hill,Western,Kashi Nath Thapa Magar,M,23/03/1981,1981,Arghakhanchi,Om Bahadur Thapa,00/02/2002,2002,Butwal,Rupandehi\nDeath,Baglung,Dhawalagiri,Hill,Western,Bak Bahadur Gharti Magar,M,29/06/1977,1977,Baglung,Bal Bir Gharti Magar,11/3/2002,2002,Baglung,Baglung\nDeath,Baglung,Dhawalagiri,Hill,Western,Bhim Kumari Gauchan,F,4/7/1959,1959,Baglung,Dal Bahadur Sherchan,11/3/2002,2002,Baglung,Baglung\nDeath,Baglung,Dhawalagiri,Hill,Western,Surya Prasad Sharma,M,27/09/1963,1963,Baglung,Nanda Ram Sharma,14/01/2002,2002,Srinagar-Pul,Baglung\nDeath,Baglung,Dhawalagiri,Hill,Western,Gopal Singh Dhami,M,00/00/1986,1986,Baitadi,Lale Dhami,26/06/2003,2003,Siddheshwor,Baitadi\nDeath,Baitadi,Mahakali,Hill,Far-Western,Narad Pandey,M,21/02/1968,1968,Baitadi,Jaya Bahadur Pandey,3/6/2002,2002,Amargadhi,Dadeldhura\nDeath,Baitadi,Mahakali,Hill,Far-Western,Surendra Singh Thagunna,M,00/00/1971,1971,Baitadi,Krishna Singh Thagunna,1/7/2002,2002,Mahendranagar,Kanchanpur\nDeath,Baitadi,Mahakali,Hill,Far-Western,Tika Datta Bhattarai,M,22/08/1960,1960,Unknown,Lal Datta Bhattarai,00/05/2001,2001,Baliya,Kailali\nDeath,Banke,Bheri,Terai,Mid-Western,Ajjoddhya Prasad Godiya,M,17/08/1983,1983,Banke,Bihari Godiya,30/10/2003,2003,Gangapur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Barmhadin Godiya,M,00/00/1989,1989,Banke,Ram Sagar Godiya,9/11/2003,2003,Phatepur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Bhoj Raj Dhakal,M,3/4/1967,1967,Kaski,Chudamani Dhakal,10/9/2002,2002,Kohalpur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Bihari Godiya,M,00/00/1944,1944,Banke,Santu Godiya,30/10/2003,2003,Dandara,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Bishnu Tharu,M,00/00/1976,1976,Banke,Sreeram Tharu,14/09/2003,2003,Phatepur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Damanti Pun,F,00/00/1981,1981,Banke,Jagat Man Pun,23/02/2002,2002,Kohalpur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Dambar Bahadur Ranabhat,M,28/04/1978,1978,Banke,Bam Bahadur Ranabhat,23/02/2002,2002,Chisapani,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Jun Kumari Gharti Magar,F,21/07/1978,1978,Rolpa,Man Bahadur Gharti Magar,8/2/1999,1999,Khajura-Khurda,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Kamal Bahadur Dahal,M,28/08/1966,1966,Dolakha,Bhim Bahadur Dahal,1/1/2002,2002,Bankatawa,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Khadak Bahadur Khadka,M,00/00/1966,1966,Salyan,Mitra Lal Khadka,19/03/2002,2002,Rajapur,Bardiya\nDeath,Banke,Bheri,Terai,Mid-Western,Khadak Bahadur Shrestha,M,16/10/1983,1983,Surkhet,Man Bahadur Shrestha,00/08/2003,2003,Mangalsen,Achham\nDeath,Banke,Bheri,Terai,Mid-Western,Mohan Lal Oli,M,12/6/1967,1967,Rukum,Chura Singh Oli,12/6/1998,1998,Mahadevpuri,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Nayab Khan,M,00/00/1948,1948,Banke,Ajanta Khan,12/9/2003,2003,Narainapur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Pratima Gautam,F,10/12/1980,1980,Banke,Kantu Ram Gautam,11/2/2002,2002,Udarapur,Banke\nDeath,Banke,Bheri,Terai,Mid-Western,Prem Bahadur Bhadel,M,00/03/1950,1950,Salyan,Bhairav Bahadur Bhadel,1/4/2002,2002,Khalanga,Salyan\nDeath,Banke,Bheri,Terai,Mid-Western,Sitala Rana,F,15/02/1987,1987,Salyan,Chuwase Rana,4/10/2003,2003,Gangapur,Banke\nDeath,Bara,Narayani,Terai,Central,Chhotelal Prasad Kushwaha,M,00/00/1978,1978,Bara,Jagarnath Mahato,18/01/2002,2002,Malangwa,Sarlahi\nDeath,Bara,Narayani,Terai,Central,Durga Hazara,M,00/00/ ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
file = pd.read_csv('People disappeared during Maoist war.csv')

# %%
file.head(3)
# Out:
#   Missing/Dead District  Zone Geographical Region Development Region  \
# 0        Death   Achham  Seti                Hill        Far-Western
# 1        Death   Achham  Seti                Hill        Far-Western
# 2        Death   Achham  Seti                Hill        Far-Western
#
#             Full Name Gender Date of Birth  Year of birth Place Of Birth  \
# 0  Bhoj Bahadur Mijar      M    00/00/1972           1972         Achham
# 1  Dabal Bahadur Saud      M    00/11/1959           1959         Achham
# 2   Padam Raj Neupane      M    00/00/1985           1985         Achham
#
#       Father'S Name Date of disapperance  Year of disaaperance  \
# 0      Bhaire Mijar           20/11/2002                  2002
# 1  Dal Bahadur Saud             3/9/2004                  2004
# 2  Umakanta Neupane             5/3/2005                  2005
#
#   Place of disapperance District of disapperance
# 0               Dipayal                     Doti
# 1             Ramarosan                   Achham
# 2             Batulasen                   Achham

# %% [markdown]
# ##### Rename the column

# %%
file.rename(columns={'Missing/Dead': 'miss_dead', 'Geographical Region': 'geo_region', 'evelopment Region':'dev_region', "Father'S Name":'Father_name'}, inplace=True)

# %%
file.head(3)
# Out:
#   miss_dead District  Zone geo_region Development Region           Full Name  \
# 0     Death   Achham  Seti       Hill        Far-Western  Bhoj Bahadur Mijar
# 1     Death   Achham  Seti       Hill        Far-Western  Dabal Bahadur Saud
# 2     Death   Achham  Seti       Hill        Far-Western   Padam Raj Neupane
#
#   Gender Date of Birth  Year of birth Place Of Birth       Father_name  \
# 0      M    00/00/1972           1972         Achham      Bhaire Mijar
# 1      M    00/11/1959           1959         Achham  Dal Bahadur Saud
# 2      M    00/00/1985           1985         Achham  Umakanta Neupane
#
#   Date of disapperance  Year of disaaperance Place of disapperance  \
# 0           20/11/2002                  2002               Dipayal
# 1             3/9/2004                  2004             Ramarosan
# 2             5/3/2005                  2005             Batulasen
#
#   District of disapperance
# 0                     Doti
# 1                   Achham
# 2                   Achham

# %%
total = len(file)
ax = sns.countplot('miss_dead',data=file)
for p in ax.patches:
        ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+5))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# In every 100 missing/dead people during the war, about 30 of them are found dead and rest 70 are still missing.

# %%
ax = sns.countplot('miss_dead',data=file,hue='Gender',palette=[ "C1","C2"])
for p in ax.patches:
        ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+5))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
# for every 1000 people dead/missing during the war, 268 of dead people are male and 32 of dead are female similarly 627 missing people are male and 72 are female missing.

# %%
district_datst = file['Place Of Birth'].unique()
list_of_district = ['Bhojpur','Dhankuta','Morang','Sankhuwasabha','Sunsari','Terathum','Illam','Jhapa','Panchthar','Taplejung','Khotang','Okhaldhunga','Saptari','Siraha','Solukhumbu','Udayapur','Bhaktapur','Dhading','Kathmandu','Kavrepalanchok','Lalitpur','Nuwakot','Rasuwa','Sindhupalchowk','Dhanusa','Dolkha','Mahottari','Ramechhap','Sarlahi','Sindhuli','Bara','Chitwan','Makwanpur','Parsa','Rautahat','Baglung','Mustang','Myagdi','Parbat','Gorkha','Kaski','Lamjung','Manang','Syangja','Tanahu','Arghakhanchi','Gulmi','Kapilvastu','Nawalparasi','Palpa','Rupandehi','Banke','Bardiya','Dailekh','Jajarkot','Surkhet','Dolpa','Humla','Jumla','Kalikot','Mugu','Dang','Pyuthan','Rolpa','Rukum','Salyan','Baidadi','Dadeldhura','Darchula','Kanchanpur','Achham','Bajhang','Bajura','Doti','Kailali']
print(list(set(list_of_district) - set(district_datst)))
list(set(district_datst) - set(list_of_district))
# Out:
# ['Solukhumbu', 'Baidadi', 'Illam', 'Kavrepalanchok', 'Terathum', 'Dolkha', 'Kapilvastu', 'Manang', 'Mustang', 'Bajura']
# ['Dolakha',
#  'Unknown',
#  'Kavrepalanchowk',
#  'Baitadi',
#  'Terhathum',
#  'Ilam',
#  'Solukhumbhu',
#  'Kapilbastu']

# %%
###### There is no official documentation for people from 3 district viz 'Manang','Bajura' and 'Mustang'.

# %%
sns.set(rc={'figure.figsize':(11.7,17)})
by_place = file.groupby('Place Of Birth').count()
by_place.reset_index(level=0, inplace=True)
# by_place.sort_values()
sns.barplot(y='Place Of Birth',x='District',data=by_place.sort_values(by='District',ascending=False))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
###### bardiya, dang and rolpa district have more complaints in people missing/dead.

# %%
file['Year of birth'].value_counts()
# Out:
# 1980    77
# 1979    75
# 1983    75
# 1982    71
# 1984    68
# 1981    68
# 1977    65
# 1978    61
# 1975    53
# 1976    48
# 1985    48
# 1971    46
# 1974    43
# 1969    41
# 1972    40
# 1986    36
# 1970    36
# 1973    32
# 1967    30
# 1987    27
# 1968    27
# 1966    25
# 1963    21
# 1961    21
# 1965    20
# 1959    19
# 1962    19
# 1964    16
# 1958    15
# 1988    13
# 1989    13
# 1960    11
# 1953     9
# 1956     9
# 1957     9
# 1950     8
# 1951     7
# 1955     7
# 1948     7
# 1946     6
# 1945     5
# 1949     4
# 1944     4
# 1990     4
# 1947     3
# 1941     3
# 1992     3
# 1954     3
# 1952     2
# 1991     2
# 1942     1
# 1940     1
# 2001     1
# 1943     1
# 1999     1
# 1938     1
# Name: Year of birth, dtype: int64

# %%
###### Those people who are dead/missing are mostly born inbetween 1975-1983 as moist war last from 1996 to 2006. So,when the war was started they are at the age between 13-23

# %%
sns.boxplot(x='Development Region',hue='miss_dead',y='Year of disaaperance',data=file)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])

# %%
##### 1)People start missing from Western development region
##### 2)There is very few dead people report from Mid-Western Development Region
##### 3)After year 2003 people missing/dead report from Far-Western and Mid-western are reduced dramatically.

# %%
file.groupby('Zone').describe()
# Out:
#             Year of birth                                                   \
#                     count         mean        std     min      25%     50%
# Zone
# Bagmati             187.0  1974.133690   8.879013  1941.0  1968.00  1976.0
# Bheri               448.0  1975.040179   9.588313  1943.0  1970.00  1978.0
# Dhawalagiri          28.0  1974.928571   8.498055  1958.0  1970.50  1975.0
# Gandaki             101.0  1972.930693   9.776766  1945.0  1968.00  1976.0
# Janakpur             48.0  1972.500000  10.601084  1947.0  1963.75  1975.0
# Karnali              53.0  1980.301887   6.506165  1966.0  1978.00  1982.0
# Kosi                 56.0  1973.714286  11.366161  1944.0  1968.75  1977.0
# Lumbini              54.0  1977.111111   8.542163  1950.0  1971.25  1980.0
# Mahakali             47.0  1975.702128   9.864109  1941.0  1971.00  1977.0
# Mechi                29.0  1976.206897   7.153317  1957.0  1971.00  1977.0
# Narayani             72.0  1969.805556  11.651801  1940.0  1962.75  1972.0
# Rapti               131.0  1974.221374  10.538786  1944.0  1969.00  1978.0
# Sagarmatha           63.0  1973.476190  10.346976  1942.0  1969.00  1974.0
# Seti                 44.0  1974.250000  11.375463  1938.0  1967.75  1975.5
#
#                              Year of disaaperance                         \
#                  75%     max                count         mean       std
# Zone
# Bagmati      1981.00  1988.0                187.0  2002.786096  1.588676
# Bheri        1982.00  1992.0                448.0  2002.104911  1.260366
# Dhawalagiri  1982.00  1988.0                 28.0  2002.392857  1.257254
# Gandaki      1979.00  1986.0                101.0  2001.910891  2.059607
# Janakpur     1980.00  1987.0                 48.0  2002.625000  1.632450
# Karnali      1985.00  1989.0                 53.0  2002.245283  1.543045
# Kosi         1981.00  1999.0                 56.0  2003.250000  1.620886
# Lumbini      1983.50  1992.0                 54.0  2002.759259  1.989929
# Mahakali     1983.00  1992.0                 47.0  2001.914894  1.212790
# Mechi        1982.00  1988.0                 29.0  2003.068966  1.162849
# Narayani     1979.25  1985.0                 72.0  2002.791667  1.519243
# Rapti        1982.00  1990.0                131.0  2001.160305  1.932781
# Sagarmatha   1981.00  2001.0                 63.0  2003.047619  1.660048
# Seti         1984.00  1990.0                 44.0  2002.727273  1.086142
#
#
#                 min      25%     50%     75%     max
# Zone
# Bagmati      1996.0  2002.00  2003.0  2004.0  2006.0
# Bheri        1998.0  2002.00  2002.0  2002.0  2006.0
# Dhawalagiri  2000.0  2002.00  2002.0  2003.0  2006.0
# Gandaki      1996.0  2001.00  2002.0  2004.0  2006.0
# Janakpur     1998.0  2002.75  2003.0  2003.0  2006.0
# Karnali      1997.0  2002.00  2002.0  2003.0  2005.0
# Kosi         1998.0  2002.00  2003.0  2004.0  2006.0
# Lumbini      1998.0  2002.00  2003.0  2004.0  2006.0
# Mahakali     1996.0  2002.00  2002.0  2002.0  2005.0
# Mechi        2001.0  2002.00  2003.0  2004.0  2006.0
# Narayani     1998.0  2002.00  2003.0  2004.0  2006.0
# Rapti        1996.0  2000.00  2002.0  2002.0  2005.0
# Sagarmatha   1999.0  2002.00  2003.0  2004.0  2006.0
# Seti         2001.0  2002.00  2002.0  2003.0  2005.0
